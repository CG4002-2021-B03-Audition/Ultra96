# %%
from pynq import allocate
from pynq import Overlay
import numpy as np
import pynq.lib.dma
import time
import pynq
import pandas as pd

# %%
weight_0 = np.load('weights_final/weight_0.npy')
weight_1 = np.load('weights_final/weight_1.npy')
weight_2 = np.load('weights_final/weight_2.npy')
weight_3 = np.load('weights_final/weight_3.npy')
weight_4 = np.load('weights_final/weight_4.npy')
bias_0 = np.load('weights_final/bias_0.npy')
bias_1 = np.load('weights_final/bias_1.npy')
bias_2 = np.load('weights_final/bias_2.npy')
bias_3 = np.load('weights_final/bias_3.npy')
bias_4 = np.load('weights_final/bias_4.npy')
weight_0_pos = np.load('weights_3dance_pos/weight_0.npy')
weight_1_pos = np.load('weights_3dance_pos/weight_1.npy')
weight_2_pos = np.load('weights_3dance_pos/weight_2.npy')
weight_3_pos = np.load('weights_3dance_pos/weight_3.npy')
bias_0_pos = np.load('weights_3dance_pos/bias_0.npy')
bias_1_pos = np.load('weights_3dance_pos/bias_1.npy')
bias_2_pos = np.load('weights_3dance_pos/bias_2.npy')
bias_3_pos = np.load('weights_3dance_pos/bias_3.npy')
scaler_mean = np.load('weights_final/mean.npy')
scaler_scale = np.load('weights_final/scale.npy')
scaler_mean_pos = np.load('weights_3dance_pos/scaler_mean.npy')
scaler_scale_pos = np.load('weights_3dance_pos/scaler_scale.npy')

# %%
df1 = pd.read_csv("dataset_3dance_pos/dancedata.csv")
y_training_pos = pd.Series(df1.LABEL).transpose()
X_training_pos = df1.drop(['Unnamed: 0', 'LABEL'], axis=1).values
X_training_pos = (X_training_pos - scaler_mean_pos) / scaler_scale_pos

# %%
df = pd.read_csv("dataset_final/dancedata.csv")
y_training = pd.Series(df.LABEL).transpose()
X_training = df.drop(['Unnamed: 0', 'LABEL'], axis=1).values
X_training = (X_training - scaler_mean) / scaler_scale

# %%
overlay = Overlay('final.bit')   # load bitstream inside FPGA
dma = overlay.axi_dma_0

# %%
choose_model = allocate(shape=(1,), dtype=np.float32)
input_buffer0 = allocate(shape=(100,), dtype=np.float32)
input_buffer1 = allocate(shape=(128,), dtype=np.float32)
input_buffer2 = allocate(shape=(12,), dtype=np.float32)
input_buffer3 = allocate(shape=(32,), dtype=np.float32)
input_buffer4 = allocate(shape=(3,), dtype=np.float32)
output_buffer0 = allocate(shape=(12,), dtype=np.float32)
output_buffer1 = allocate(shape=(3,), dtype=np.float32)

# %%
##load dance weights
for i in range(128):
    for k in range(100):
        input_buffer0[k] = weight_0[k][i]
    dma.sendchannel.transfer(input_buffer0)
    dma.sendchannel.wait()
for i in range(128):
    for k in range(128):
        input_buffer1[k] = weight_1[k][i]
    dma.sendchannel.transfer(input_buffer1)
    dma.sendchannel.wait()
for i in range(128):
    for k in range(128):
        input_buffer1[k] = weight_2[k][i]
    dma.sendchannel.transfer(input_buffer1)
    dma.sendchannel.wait()
for i in range(128):
    for k in range(128):
        input_buffer1[k] = weight_3[k][i]
    dma.sendchannel.transfer(input_buffer1)
    dma.sendchannel.wait()
for i in range(12):
    for k in range(128):
        input_buffer1[k] = weight_4[k][i]
    dma.sendchannel.transfer(input_buffer1)
    dma.sendchannel.wait()
##bias
for k in range(128):
    input_buffer1[k] = bias_0[k]
dma.sendchannel.transfer(input_buffer1)
dma.sendchannel.wait()
for k in range(128):
    input_buffer1[k] = bias_1[k]
dma.sendchannel.transfer(input_buffer1)
dma.sendchannel.wait()
for k in range(128):
    input_buffer1[k] = bias_2[k]
dma.sendchannel.transfer(input_buffer1)
dma.sendchannel.wait()
for k in range(128):
    input_buffer1[k] = bias_3[k]
dma.sendchannel.transfer(input_buffer1)
dma.sendchannel.wait()
for k in range(12):
    input_buffer2[k] = bias_4[k]
dma.sendchannel.transfer(input_buffer2)
dma.sendchannel.wait()

# %%
##load position weights
for i in range(32):
    for k in range(100):
        input_buffer0[k] = weight_0_pos[k][i]
    dma.sendchannel.transfer(input_buffer0)
    dma.sendchannel.wait()
for i in range(32):
    for k in range(32):
        input_buffer3[k] = weight_1_pos[k][i]
    dma.sendchannel.transfer(input_buffer3)
    dma.sendchannel.wait()
for i in range(32):
    for k in range(32):
        input_buffer3[k] = weight_2_pos[k][i]
    dma.sendchannel.transfer(input_buffer3)
    dma.sendchannel.wait()
for i in range(3):
    for k in range(32):
        input_buffer3[k] = weight_3_pos[k][i]
    dma.sendchannel.transfer(input_buffer3)
    dma.sendchannel.wait()
##bias
for k in range(32):
    input_buffer3[k] = bias_0_pos[k]
dma.sendchannel.transfer(input_buffer3)
dma.sendchannel.wait()
for k in range(32):
    input_buffer3[k] = bias_1_pos[k]
dma.sendchannel.transfer(input_buffer3)
dma.sendchannel.wait()
for k in range(32):
    input_buffer3[k] = bias_2_pos[k]
dma.sendchannel.transfer(input_buffer3)
dma.sendchannel.wait()
for k in range(3):
    input_buffer4[k] = bias_3_pos[k]
dma.sendchannel.transfer(input_buffer4)
dma.sendchannel.wait()

# %%
def fpga_evaluate_dance(test):
    choose_model[0] = 0
    dma.sendchannel.transfer(choose_model)
    dma.sendchannel.wait()
    for j in range(100):
        input_buffer0[j] = test[j];
    dma.sendchannel.transfer(input_buffer0)
    dma.recvchannel.transfer(output_buffer0)
    dma.sendchannel.wait()
    dma.recvchannel.wait()
    return output_buffer0

# %%
def fpga_evaluate_pos(test):
    choose_model[0] = 1
    dma.sendchannel.transfer(choose_model)
    dma.sendchannel.wait()
    for j in range(100):
        input_buffer0[j] = test[j];
    dma.sendchannel.transfer(input_buffer0)
    dma.recvchannel.transfer(output_buffer1)
    dma.sendchannel.wait()
    dma.recvchannel.wait()
    return output_buffer1

# %%
X_training.shape
# Out:
# (8351, 100)

# %%
fpga_res = np.zeros(12)
for i in range(X_training.shape[0]):
    fpga_res = np.row_stack((fpga_res, fpga_evaluate_dance(X_training[i])))
fpga_res = fpga_res[1:]

# %%
fpga_res = np.argmax(fpga_res, axis=-1)

# %%
labels = np.array(['dab', 'elbowkick', 'gun', 'hair', 'left', 'listen', 'pointhigh', 'right', 'sidepump', 'special', 'stationary', 'wipetable'])
decoded_predictions = labels[fpga_res]

# %%
from IPython.display import display
dataset = pd.DataFrame({'FPGA predictions': decoded_predictions, 'Actual test label': y_training}).reset_index(drop=True)
pd.set_option('display.max_rows', 300)
pd.set_option('display.height', 300)
display(dataset)
# Out:
#      Actual test label FPGA predictions
# 0                  dab       stationary
# 1                  dab             left
# 2                  dab             left
# 3                  dab       stationary
# 4                  dab              dab
# 5                  dab              dab
# 6                  dab         sidepump
# 7                  dab              dab
# 8                  dab              dab
# 9                  dab              dab
# 10                 dab              dab
# 11                 dab              dab
# 12                 dab              dab
# 13                 dab              dab
# 14                 dab              dab
# 15                 dab              dab
# 16                 dab              dab
# 17                 dab              dab
# 18                 dab              dab
# 19                 dab              dab
# 20                 dab              dab
# 21                 dab              dab
# 22                 dab              dab
# 23                 dab              dab
# 24                 dab              dab
# 25                 dab              dab
# 26                 dab              dab
# 27                 dab              dab
# 28                 dab              dab
# 29                 dab              dab
# 30                 dab              dab
# 31                 dab              dab
# 32                 dab              dab
# 33                 dab              dab
# 34                 dab              dab
# 35                 dab              dab
# 36                 dab              dab
# 37                 dab              dab
# 38                 dab              dab
# 39                 dab              dab
# 40                 dab              dab
# 41                 dab              dab
# 42                 dab              dab
# 43                 dab              dab
# 44                 dab              dab
# 45                 dab              dab
# 46                 dab              dab
# 47                 dab              dab
# 48                 dab              dab
# 49                 dab              dab
# 50                 dab              dab
# 51                 dab              dab
# 52                 dab              dab
# 53                 dab              dab
# 54                 dab              dab
# 55                 dab              dab
# 56                 dab              dab
# 57                 dab              dab
# 58                 dab              dab
# 59                 dab              dab
# 60                 dab              dab
# 61                 dab              dab
# 62                 dab              dab
# 63                 dab              dab
# 64                 dab              dab
# 65                 dab              dab
# 66                 dab              dab
# 67                 dab              dab
# 68                 dab              dab
# 69                 dab              dab
# 70                 dab              dab
# 71                 dab              dab
# 72                 dab              dab
# 73                 dab              dab
# 74                 dab              dab
# 75                 dab              dab
# 76                 dab              dab
# 77                 dab              dab
# 78                 dab              dab
# 79                 dab              dab
# 80                 dab              dab
# 81                 dab              dab
# 82                 dab              dab
# 83                 dab              dab
# 84                 dab              dab
# 85                 dab              dab
# 86                 dab              dab
# 87                 dab              dab
# 88                 dab              dab
# 89                 dab              dab
# 90                 dab              dab
# 91                 dab              dab
# 92                 dab              dab
# 93                 dab              dab
# 94                 dab              dab
# 95                 dab              dab
# 96                 dab              dab
# 97                 dab              dab
# 98                 dab              dab
# 99                 dab              dab
# 100                dab              dab
# 101                dab              dab
# 102                dab              dab
# 103                dab              dab
# 104                dab              dab
# 105                dab              dab
# 106                dab              dab
# 107                dab              dab
# 108                dab              dab
# 109                dab              dab
# 110                dab              dab
# 111                dab              dab
# 112                dab              dab
# 113                dab              dab
# 114                dab              dab
# 115                dab              dab
# 116                dab              dab
# 117                dab              dab
# 118                dab              dab
# 119                dab              dab
# 120                dab              dab
# 121                dab              dab
# 122                dab              dab
# 123                dab              dab
# 124                dab              dab
# 125                dab              dab
# 126                dab              dab
# 127                dab              dab
# 128                dab              dab
# 129                dab              dab
# 130                dab              dab
# 131                dab              dab
# 132                dab              dab
# 133                dab              dab
# 134                dab              dab
# 135                dab              dab
# 136                dab              dab
# 137                dab              dab
# 138                dab              dab
# 139                dab              dab
# 140                dab              dab
# 141                dab              dab
# 142                dab              dab
# 143                dab              dab
# 144                dab              dab
# 145                dab              dab
# 146                dab              dab
# 147                dab              dab
# 148                dab              dab
# 149                dab              dab
# ...                ...              ...
# 8201         wipetable        wipetable
# 8202         wipetable        wipetable
# 8203         wipetable        wipetable
# 8204         wipetable        wipetable
# 8205         wipetable        wipetable
# 8206         wipetable        wipetable
# 8207         wipetable        wipetable
# 8208         wipetable        wipetable
# 8209         wipetable        wipetable
# 8210         wipetable        wipetable
# 8211         wipetable        wipetable
# 8212         wipetable        wipetable
# 8213         wipetable        wipetable
# 8214         wipetable        wipetable
# 8215         wipetable        wipetable
# 8216         wipetable        wipetable
# 8217         wipetable        wipetable
# 8218         wipetable        wipetable
# 8219         wipetable        wipetable
# 8220         wipetable        wipetable
# 8221         wipetable              dab
# 8222         wipetable        wipetable
# 8223         wipetable        wipetable
# 8224         wipetable        wipetable
# 8225         wipetable        wipetable
# 8226         wipetable        wipetable
# 8227         wipetable        wipetable
# 8228         wipetable        wipetable
# 8229         wipetable        wipetable
# 8230         wipetable        wipetable
# 8231         wipetable        wipetable
# 8232         wipetable        wipetable
# 8233         wipetable        wipetable
# 8234         wipetable        wipetable
# 8235         wipetable        wipetable
# 8236         wipetable        wipetable
# 8237         wipetable        wipetable
# 8238         wipetable        wipetable
# 8239         wipetable        wipetable
# 8240         wipetable        wipetable
# 8241         wipetable        wipetable
# 8242         wipetable        wipetable
# 8243         wipetable        wipetable
# 8244         wipetable        wipetable
# 8245         wipetable        wipetable
# 8246         wipetable        wipetable
# 8247         wipetable        wipetable
# 8248         wipetable        wipetable
# 8249         wipetable        wipetable
# 8250         wipetable        wipetable
# 8251         wipetable        wipetable
# 8252         wipetable        wipetable
# 8253         wipetable        wipetable
# 8254         wipetable        wipetable
# 8255         wipetable        wipetable
# 8256         wipetable        wipetable
# 8257         wipetable        wipetable
# 8258         wipetable        wipetable
# 8259         wipetable        wipetable
# 8260         wipetable        wipetable
# 8261         wipetable        wipetable
# 8262         wipetable        wipetable
# 8263         wipetable        wipetable
# 8264         wipetable        wipetable
# 8265         wipetable        wipetable
# 8266         wipetable        wipetable
# 8267         wipetable        wipetable
# 8268         wipetable        wipetable
# 8269         wipetable        wipetable
# 8270         wipetable        wipetable
# 8271         wipetable        wipetable
# 8272         wipetable        wipetable
# 8273         wipetable        wipetable
# 8274         wipetable        wipetable
# 8275         wipetable        wipetable
# 8276         wipetable        wipetable
# 8277         wipetable        wipetable
# 8278         wipetable        wipetable
# 8279         wipetable        wipetable
# 8280         wipetable        wipetable
# 8281         wipetable        wipetable
# 8282         wipetable        wipetable
# 8283         wipetable        wipetable
# 8284         wipetable        wipetable
# 8285         wipetable        wipetable
# 8286         wipetable        wipetable
# 8287         wipetable        wipetable
# 8288         wipetable        wipetable
# 8289         wipetable        wipetable
# 8290         wipetable        wipetable
# 8291         wipetable        wipetable
# 8292         wipetable        wipetable
# 8293         wipetable        wipetable
# 8294         wipetable        wipetable
# 8295         wipetable        wipetable
# 8296         wipetable        wipetable
# 8297         wipetable        wipetable
# 8298         wipetable        wipetable
# 8299         wipetable        wipetable
# 8300         wipetable        wipetable
# 8301         wipetable        wipetable
# 8302         wipetable        wipetable
# 8303         wipetable        wipetable
# 8304         wipetable        wipetable
# 8305         wipetable        wipetable
# 8306         wipetable        wipetable
# 8307         wipetable        wipetable
# 8308         wipetable        wipetable
# 8309         wipetable        wipetable
# 8310         wipetable        wipetable
# 8311         wipetable        wipetable
# 8312         wipetable        wipetable
# 8313         wipetable        wipetable
# 8314         wipetable        wipetable
# 8315         wipetable        wipetable
# 8316         wipetable        wipetable
# 8317         wipetable        wipetable
# 8318         wipetable        wipetable
# 8319         wipetable        wipetable
# 8320         wipetable        wipetable
# 8321         wipetable        wipetable
# 8322         wipetable        wipetable
# 8323         wipetable        wipetable
# 8324         wipetable        wipetable
# 8325         wipetable        wipetable
# 8326         wipetable        wipetable
# 8327         wipetable        wipetable
# 8328         wipetable        wipetable
# 8329         wipetable        wipetable
# 8330         wipetable        wipetable
# 8331         wipetable        wipetable
# 8332         wipetable        wipetable
# 8333         wipetable        wipetable
# 8334         wipetable        wipetable
# 8335         wipetable        wipetable
# 8336         wipetable        wipetable
# 8337         wipetable        wipetable
# 8338         wipetable        wipetable
# 8339         wipetable        wipetable
# 8340         wipetable        wipetable
# 8341         wipetable        wipetable
# 8342         wipetable        wipetable
# 8343         wipetable        wipetable
# 8344         wipetable        wipetable
# 8345         wipetable        wipetable
# 8346         wipetable        wipetable
# 8347         wipetable        wipetable
# 8348         wipetable        wipetable
# 8349         wipetable        wipetable
# 8350         wipetable        wipetable
#
# [8351 rows x 2 columns]

# %%
fpga_pos_res = np.zeros(3)
for i in range(X_training_pos.shape[0]):
    fpga_pos_res = np.row_stack((fpga_pos_res, fpga_evaluate_pos(X_training_pos[i])))
fpga_pos_res = fpga_pos_res[1:]

# %%
fpga_pos_res = np.argmax(fpga_pos_res, axis=-1)

# %%
labels_pos = np.array(['left', 'right', 'stationary'])
decoded_pos_predictions = labels_pos[fpga_pos_res]

# %%
from IPython.display import display
dataset_pos = pd.DataFrame({'FPGA predictions': decoded_pos_predictions, 'Actual test label': y_training_pos}).reset_index(drop=True)
pd.set_option('display.max_rows', 300)
pd.set_option('display.height', 300)
display(dataset_pos)
# Out:
#      Actual test label FPGA predictions
# 0                 left             left
# 1                 left             left
# 2                 left             left
# 3                 left             left
# 4                 left             left
# 5                 left             left
# 6                 left             left
# 7                 left             left
# 8                 left             left
# 9                 left             left
# 10                left             left
# 11                left             left
# 12                left             left
# 13                left             left
# 14                left             left
# 15                left             left
# 16                left             left
# 17                left             left
# 18                left             left
# 19                left             left
# 20                left             left
# 21                left             left
# 22                left             left
# 23                left             left
# 24                left             left
# 25                left             left
# 26                left             left
# 27                left             left
# 28                left             left
# 29                left             left
# 30                left             left
# 31                left             left
# 32                left             left
# 33                left             left
# 34                left             left
# 35                left             left
# 36                left             left
# 37                left             left
# 38                left             left
# 39                left             left
# 40                left             left
# 41                left             left
# 42                left             left
# 43                left             left
# 44                left             left
# 45                left             left
# 46                left             left
# 47                left             left
# 48                left             left
# 49                left             left
# 50                left             left
# 51                left             left
# 52                left             left
# 53                left             left
# 54                left             left
# 55                left             left
# 56                left             left
# 57                left             left
# 58                left             left
# 59                left             left
# 60                left             left
# 61                left             left
# 62                left             left
# 63                left             left
# 64                left             left
# 65                left             left
# 66                left             left
# 67                left             left
# 68                left             left
# 69                left             left
# 70                left             left
# 71                left             left
# 72                left             left
# 73                left             left
# 74                left             left
# 75                left             left
# 76                left             left
# 77                left             left
# 78                left             left
# 79                left             left
# 80                left             left
# 81                left             left
# 82                left             left
# 83                left             left
# 84                left             left
# 85                left             left
# 86                left             left
# 87                left             left
# 88                left             left
# 89                left             left
# 90                left            right
# 91                left             left
# 92                left             left
# 93                left             left
# 94                left             left
# 95                left             left
# 96                left             left
# 97                left             left
# 98                left             left
# 99                left             left
# 100               left             left
# 101               left             left
# 102               left             left
# 103               left             left
# 104               left             left
# 105               left             left
# 106               left             left
# 107               left             left
# 108               left             left
# 109               left             left
# 110               left             left
# 111               left             left
# 112               left             left
# 113               left             left
# 114               left             left
# 115               left             left
# 116               left             left
# 117               left             left
# 118               left             left
# 119               left             left
# 120               left             left
# 121               left             left
# 122               left             left
# 123               left             left
# 124               left             left
# 125               left             left
# 126               left             left
# 127               left             left
# 128               left             left
# 129               left             left
# 130               left             left
# 131               left             left
# 132               left             left
# 133               left             left
# 134               left             left
# 135               left             left
# 136               left             left
# 137               left             left
# 138               left             left
# 139               left             left
# 140               left             left
# 141               left             left
# 142               left             left
# 143               left             left
# 144               left             left
# 145               left            right
# 146               left            right
# 147               left             left
# 148               left             left
# 149               left             left
# ...                ...              ...
# 1133        stationary       stationary
# 1134        stationary       stationary
# 1135        stationary       stationary
# 1136        stationary       stationary
# 1137        stationary       stationary
# 1138        stationary       stationary
# 1139        stationary       stationary
# 1140        stationary       stationary
# 1141        stationary       stationary
# 1142        stationary       stationary
# 1143        stationary       stationary
# 1144        stationary       stationary
# 1145        stationary       stationary
# 1146        stationary       stationary
# 1147        stationary       stationary
# 1148        stationary       stationary
# 1149        stationary       stationary
# 1150        stationary       stationary
# 1151        stationary       stationary
# 1152        stationary       stationary
# 1153        stationary       stationary
# 1154        stationary       stationary
# 1155        stationary       stationary
# 1156        stationary       stationary
# 1157        stationary       stationary
# 1158        stationary       stationary
# 1159        stationary       stationary
# 1160        stationary       stationary
# 1161        stationary       stationary
# 1162        stationary       stationary
# 1163        stationary       stationary
# 1164        stationary       stationary
# 1165        stationary       stationary
# 1166        stationary       stationary
# 1167        stationary       stationary
# 1168        stationary       stationary
# 1169        stationary       stationary
# 1170        stationary       stationary
# 1171        stationary       stationary
# 1172        stationary       stationary
# 1173        stationary       stationary
# 1174        stationary       stationary
# 1175        stationary       stationary
# 1176        stationary       stationary
# 1177        stationary       stationary
# 1178        stationary       stationary
# 1179        stationary       stationary
# 1180        stationary       stationary
# 1181        stationary       stationary
# 1182        stationary       stationary
# 1183        stationary       stationary
# 1184        stationary       stationary
# 1185        stationary       stationary
# 1186        stationary       stationary
# 1187        stationary       stationary
# 1188        stationary       stationary
# 1189        stationary       stationary
# 1190        stationary       stationary
# 1191        stationary       stationary
# 1192        stationary       stationary
# 1193        stationary       stationary
# 1194        stationary       stationary
# 1195        stationary       stationary
# 1196        stationary       stationary
# 1197        stationary       stationary
# 1198        stationary       stationary
# 1199        stationary       stationary
# 1200        stationary       stationary
# 1201        stationary       stationary
# 1202        stationary       stationary
# 1203        stationary       stationary
# 1204        stationary       stationary
# 1205        stationary       stationary
# 1206        stationary       stationary
# 1207        stationary       stationary
# 1208        stationary       stationary
# 1209        stationary       stationary
# 1210        stationary       stationary
# 1211        stationary       stationary
# 1212        stationary       stationary
# 1213        stationary       stationary
# 1214        stationary       stationary
# 1215        stationary       stationary
# 1216        stationary       stationary
# 1217        stationary       stationary
# 1218        stationary       stationary
# 1219        stationary       stationary
# 1220        stationary       stationary
# 1221        stationary       stationary
# 1222        stationary       stationary
# 1223        stationary       stationary
# 1224        stationary       stationary
# 1225        stationary       stationary
# 1226        stationary       stationary
# 1227        stationary       stationary
# 1228        stationary       stationary
# 1229        stationary       stationary
# 1230        stationary       stationary
# 1231        stationary       stationary
# 1232        stationary       stationary
# 1233        stationary       stationary
# 1234        stationary       stationary
# 1235        stationary       stationary
# 1236        stationary       stationary
# 1237        stationary       stationary
# 1238        stationary       stationary
# 1239        stationary       stationary
# 1240        stationary       stationary
# 1241        stationary       stationary
# 1242        stationary       stationary
# 1243        stationary       stationary
# 1244        stationary       stationary
# 1245        stationary       stationary
# 1246        stationary       stationary
# 1247        stationary       stationary
# 1248        stationary       stationary
# 1249        stationary       stationary
# 1250        stationary       stationary
# 1251        stationary       stationary
# 1252        stationary       stationary
# 1253        stationary       stationary
# 1254        stationary       stationary
# 1255        stationary       stationary
# 1256        stationary       stationary
# 1257        stationary       stationary
# 1258        stationary       stationary
# 1259        stationary       stationary
# 1260        stationary       stationary
# 1261        stationary       stationary
# 1262        stationary       stationary
# 1263        stationary       stationary
# 1264        stationary       stationary
# 1265        stationary       stationary
# 1266        stationary       stationary
# 1267        stationary       stationary
# 1268        stationary       stationary
# 1269        stationary       stationary
# 1270        stationary       stationary
# 1271        stationary       stationary
# 1272        stationary       stationary
# 1273        stationary       stationary
# 1274        stationary       stationary
# 1275        stationary       stationary
# 1276        stationary       stationary
# 1277        stationary       stationary
# 1278        stationary       stationary
# 1279        stationary       stationary
# 1280        stationary       stationary
# 1281        stationary       stationary
# 1282        stationary       stationary
#
# [1283 rows x 2 columns]
